# %% [markdown]
# # 提交流程与 Offline Compliance
#
# Kaggle-style 提交的核心只有几个文件，必须**完全离线**。
#
# 关键入口：`submission/agent.py`

# %%
from submission.agent import SubmissionAgent
import inspect
print(inspect.getsource(SubmissionAgent))

# %% [markdown]
# ## 必须通过的检查

# %%
from submission.offline_check import run_offline_check
print("Running offline compliance check (will fail if network/LLM code leaks in)...")
# run_offline_check()   # 真实项目里会调用

# %% [markdown]
# 运行：
# ```bash
# python -m submission.offline_check
# python -m submission.run --episodes 3 --checkpoint runs/smoke/checkpoints/agent.pkl
# ```
