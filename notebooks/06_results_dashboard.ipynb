# %% [markdown]
# # 训练结果与可视化
#
# 训练完后如何分析？
#
# - `arcagent.viz.report` 生成自包含 HTML 报告
# - metrics.jsonl + pbt_events.jsonl
# - 也可以直接用 pandas + matplotlib 在 notebook 里探索

# %%
from arcagent.viz import build_report
import inspect
print(inspect.getsource(build_report)[:500])

# %% [markdown]
# ## 典型用法
# 先跑一个 smoke：
# ```bash
# python -m arcagent.train.run --steps 300 --run-dir runs/my_smoke
# python -m arcagent.viz.report runs/my_smoke
# ```
#
# 然后在本 notebook 里加载 metrics 进一步分析。

# %%
# 示例：读取最近一次训练的 metrics
# import pandas as pd
# df = pd.read_json("runs/my_smoke/metrics.jsonl", lines=True)
# df.tail()
